# %%
import pandas as pd
import json
import matplotlib.pyplot as plt

# %%
import json
import pandas as pd
data = json.load(open('data-load/wg/wg_data.json'))
df = pd.DataFrame(data["recordData"])
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In [60], line 3
#       1 import json
#       2 import pandas as pd
# ----> 3 data = json.load(open('data-load/wg/wg_data.json'))
#       4 df = pd.DataFrame(data["recordData"])
#
# File ~/sw/miniconda3/envs/data/lib/python3.9/json/__init__.py:293, in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     274 def load(fp, *, cls=None, object_hook=None, parse_float=None,
#     275         parse_int=None, parse_constant=None, object_pairs_hook=None, **kw):
#     276     """Deserialize ``fp`` (a ``.read()``-supporting file-like object containing
#     277     a JSON document) to a Python object.
#     278
#    (...)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
# ...

# %%
df
# Out:
#     vehicleName         vid  surfaceTemperature   latitude  longitude  \
# 0       SV3-052  2107397055                25.0 -37.159567  16.049902
# 1       SV3-052  2107397055                25.0 -37.159555  16.049782
# 2       SV3-052  2107397055                25.0 -37.159557  16.049832
# 3       SV3-052  2107397055                25.0 -37.159548  16.049817
# 4       SV3-052  2107397055                25.0 -37.159612  16.049820
# ..          ...         ...                 ...        ...        ...
# 102     SV3-052  2107397055                23.0 -37.159578  16.048867
# 103     SV3-052  2107397055                23.0 -37.159228  16.049092
# 104     SV3-052  2107397055                23.0 -37.159562  16.049200
# 105     SV3-052  2107397055                23.0 -37.159667  16.049170
# 106     SV3-052  2107397055                23.0 -37.159655  16.049132
#
#          lastLocationFix  temperatureSub  iridiumSignalStrength  \
# ...

# %%
plt.scatter(df.longitude.iloc[-10:],df.latitude.iloc[-10:])
