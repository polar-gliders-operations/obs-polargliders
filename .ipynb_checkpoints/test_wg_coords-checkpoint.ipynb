# %%
import pandas as pd
import json

# %%
import json
import pandas as pd
data = json.load(open('wg/wg_data.json'))
df = pd.DataFrame(data["recordData"])

# %%
# Out:
#   vehicleName         vid  surfaceTemperature   latitude  longitude  \
# 0     SV3-052  2107397055                23.0 -37.159307  16.053035
# 1     SV3-052  2107397055                23.0 -37.159303  16.053107
# 2     SV3-052  2107397055                23.0 -37.159305  16.053140
# 3     SV3-052  2107397055                23.0 -37.159305  16.053107
# 4     SV3-052  2107397055                23.0 -37.159313  16.053235
# 5     SV3-052  2107397055                23.0 -37.159307  16.053253
# 6     SV3-052  2107397055                23.0 -37.159293  16.053253
#
#        lastLocationFix  temperatureSub  iridiumSignalStrength  targetWayPoint  \
# 0  2023-03-06T17:58:32            19.0                      0               2
# 1  2023-03-06T18:00:32            19.0                      4               2
# 2  2023-03-06T18:02:32            19.0                      4               2
# 3  2023-03-06T18:04:32            19.0                      0               2
# ...
